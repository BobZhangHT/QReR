# %%
import os

# %%
os.chdir("/content/drive/MyDrive/Github/QRWG")
print(os.getcwd())
# Out:
# /content/drive/MyDrive/Github/QRWG

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

from datagen import *
from network import *

# %% [markdown]
# # Data Generation

# %%
nt = 250
r = 2
tau = 1
err_std = 1

# %%
np.random.seed(123)
x, z = x_gen(nt,r)
y1, y2, y3 = y_gen(x,z,tau,err_std)

# %% [markdown]
# # QRWG Training
#
# QRWG: Quasi-Randomized Weights Generation

# %%
batch_size = 256
lr = 1e-3
pa = 0.05#np.inf
init_method = 'uniform'
num_nodes = 64
num_iters = 1500
patience = 5
save_folder = './save/'
random_state = 0

# %%
estimator = QRWG(lr=lr,
                 batch_size=batch_size,
                 patience=patience,
                 num_iters=num_iters,
                 pa=pa,
                 init_method=init_method,
                 num_nodes=num_nodes,
                 verbose=True,
                 random_state=random_state)

# %%
estimator.fit(x,z)
# Out:
# Starting Training Loop...
# [10/1500]	Total Loss: 1709.9812	MdiffLoss: 19.5341	QQLoss: 1690.4471	KS: 1.0000	Mdiff_Avg: 0.2160
# [20/1500]	Total Loss: 1136.5913	MdiffLoss: 12.2897	QQLoss: 1124.3016	KS: 1.0000	Mdiff_Avg: 0.1290
# [30/1500]	Total Loss: 389.5626	MdiffLoss: 10.9515	QQLoss: 378.6111	KS: 1.0000	Mdiff_Avg: 0.0429
# [40/1500]	Total Loss: 185.2064	MdiffLoss: 18.2740	QQLoss: 166.9324	KS: 0.8828	Mdiff_Avg: 0.0206
# [50/1500]	Total Loss: 100.9510	MdiffLoss: 13.7152	QQLoss: 87.2358	KS: 0.7891	Mdiff_Avg: 0.0046
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Update Model.
# [60/1500]	Total Loss: 65.8167	MdiffLoss: 14.3306	QQLoss: 51.4861	KS: 0.6406	Mdiff_Avg: 0.0044
# [70/1500]	Total Loss: 51.2781	MdiffLoss: 11.2763	QQLoss: 40.0018	KS: 0.5391	Mdiff_Avg: 0.0032
# [80/1500]	Total Loss: 52.7836	MdiffLoss: 17.8489	QQLoss: 34.9348	KS: 0.5234	Mdiff_Avg: 0.0034
# [90/1500]	Total Loss: 37.4870	MdiffLoss: 10.8409	QQLoss: 26.6461	KS: 0.4688	Mdiff_Avg: 0.0025
# [100/1500]	Total Loss: 38.0277	MdiffLoss: 7.5828	QQLoss: 30.4449	KS: 0.4062	Mdiff_Avg: 0.0032
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Update Model.
# [110/1500]	Total Loss: 36.8088	MdiffLoss: 10.2290	QQLoss: 26.5799	KS: 0.4492	Mdiff_Avg: 0.0037
# [120/1500]	Total Loss: 36.0574	MdiffLoss: 10.2802	QQLoss: 25.7772	KS: 0.4414	Mdiff_Avg: 0.0056
# [130/1500]	Total Loss: 29.1970	MdiffLoss: 7.8260	QQLoss: 21.3710	KS: 0.4375	Mdiff_Avg: 0.0046
# [140/1500]	Total Loss: 23.2186	MdiffLoss: 5.6625	QQLoss: 17.5561	KS: 0.4141	Mdiff_Avg: 0.0034
# [150/1500]	Total Loss: 22.9682	MdiffLoss: 6.2681	QQLoss: 16.7002	KS: 0.4023	Mdiff_Avg: 0.0027
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Update Model.
#
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [860/1500]	Total Loss: 9.6768	MdiffLoss: 3.2466	QQLoss: 6.4301	KS: 0.2812	Mdiff_Avg: 0.0041
# [870/1500]	Total Loss: 6.8377	MdiffLoss: 1.7308	QQLoss: 5.1069	KS: 0.2578	Mdiff_Avg: 0.0039
# [880/1500]	Total Loss: 8.3442	MdiffLoss: 3.3620	QQLoss: 4.9823	KS: 0.2422	Mdiff_Avg: 0.0049
# [890/1500]	Total Loss: 8.2414	MdiffLoss: 3.4179	QQLoss: 4.8235	KS: 0.2852	Mdiff_Avg: 0.0032
# [900/1500]	Total Loss: 9.5097	MdiffLoss: 3.2008	QQLoss: 6.3089	KS: 0.3320	Mdiff_Avg: 0.0045
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [910/1500]	Total Loss: 12.8305	MdiffLoss: 4.1455	QQLoss: 8.6850	KS: 0.2734	Mdiff_Avg: 0.0025
# [920/1500]	Total Loss: 8.7587	MdiffLoss: 3.0131	QQLoss: 5.7457	KS: 0.2812	Mdiff_Avg: 0.0039
# [930/1500]	Total Loss: 6.7612	MdiffLoss: 2.1452	QQLoss: 4.6160	KS: 0.3008	Mdiff_Avg: 0.0030
# [940/1500]	Total Loss: 7.9452	MdiffLoss: 2.5648	QQLoss: 5.3804	KS: 0.2930	Mdiff_Avg: 0.0039
# [950/1500]	Total Loss: 8.4234	MdiffLoss: 2.5448	QQLoss: 5.8785	KS: 0.2773	Mdiff_Avg: 0.0068
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [960/1500]	Total Loss: 7.8705	MdiffLoss: 3.1932	QQLoss: 4.6773	KS: 0.2305	Mdiff_Avg: 0.0056
# [970/1500]	Total Loss: 14.4414	MdiffLoss: 5.7034	QQLoss: 8.7380	KS: 0.2500	Mdiff_Avg: 0.0051
# [980/1500]	Total Loss: 8.0071	MdiffLoss: 2.9818	QQLoss: 5.0253	KS: 0.2656	Mdiff_Avg: 0.0053
# [990/1500]	Total Loss: 8.0099	MdiffLoss: 2.1009	QQLoss: 5.9090	KS: 0.3047	Mdiff_Avg: 0.0024
# [1000/1500]	Total Loss: 6.9396	MdiffLoss: 2.8141	QQLoss: 4.1255	KS: 0.2461	Mdiff_Avg: 0.0027
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [1010/1500]	Total Loss: 11.4858	MdiffLoss: 5.4746	QQLoss: 6.0111	KS: 0.3242	Mdiff_Avg: 0.0044
# [1020/1500]	Total Loss: 10.2362	MdiffLoss: 3.6872	QQLoss: 6.5490	KS: 0.2773	Mdiff_Avg: 0.0047
# [1030/1500]	Total Loss: 7.8766	MdiffLoss: 2.9086	QQLoss: 4.9680	KS: 0.2578	Mdiff_Avg: 0.0049
# [1040/1500]	Total Loss: 9.1065	MdiffLoss: 2.7359	QQLoss: 6.3706	KS: 0.2539	Mdiff_Avg: 0.0035
# [1050/1500]	Total Loss: 7.7717	MdiffLoss: 3.3010	QQLoss: 4.4707	KS: 0.2695	Mdiff_Avg: 0.0051
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Stop the Training.
# QRWG(batch_size=256, device='cpu', init_method='uniform', lr=0.001, ngpu=0,
#      num_iters=1500, num_nodes=64, pa=0.05, patience=5, random_state=0,
#      save_folder='./save/', verbose=True)

# %% [markdown]
# # Check Training

# %%
plt.plot(estimator.losses[100:],label='Total Loss')
plt.plot(estimator.qqlosses[100:],label='QQLoss')
plt.plot(estimator.mdifflosses[100:],label='MdiffLoss')
plt.legend()

# %%
plt.plot(estimator.x_mdiff_list)

# %%
plt.plot(estimator.ks_list)

# %%
plt.plot(estimator.val_ks_list)

# %% [markdown]
# # Check Balance

# %%
wts_mat_net = estimator.predict().numpy()

# %%
# consider rerandomization
z_mat_rer = np.array([ReR(pa,torch.Tensor(x))[0].numpy() for i in range(1000)])

# %%
mdiff_mat_net = np.array([cov_mdiff(x,z,wts_mat_net[i]) for i in range(wts_mat_net.shape[0])])
mdiff_mat_rer = np.array([cov_mdiff(x,z_mat_rer[i]) for i in range(z_mat_rer.shape[0])])

# %%
import pandas as pd

df_mdiff_net = pd.DataFrame(mdiff_mat_net,columns=['X'+str(i+1) for i in range(mdiff_mat_net.shape[1])])
df_mdiff_net['Method'] = 'QRWG'
df_mdiff_rer = pd.DataFrame(mdiff_mat_rer,columns=['X'+str(i+1) for i in range(mdiff_mat_rer.shape[1])])
df_mdiff_rer['Method'] = 'ReR'

df_mdiff = pd.concat([df_mdiff_net,df_mdiff_rer],axis=0)
df_mdiff = pd.melt(df_mdiff,id_vars=['Method'],var_name=['Variable'],value_name='Value')

# %%
plt.figure(figsize=(10,6))
sb.boxplot(x='Variable',y='Value',
           hue="Method",data=df_mdiff)
plt.ylabel('$\\bar{x}_T-\\bar{x}_C$',fontsize=12)
plt.xlabel('Covariates',fontsize=12)
# Out:
# Text(0.5, 0, 'Covariates')

# %% [markdown]
# # Inference

# %%
tau1_vec_net = np.array([tau_diff(y1,z,wts_mat_net[i]) for i in range(wts_mat_net.shape[0])])
tau2_vec_net = np.array([tau_diff(y2,z,wts_mat_net[i]) for i in range(wts_mat_net.shape[0])])
tau3_vec_net = np.array([tau_diff(y3,z,wts_mat_net[i]) for i in range(wts_mat_net.shape[0])])

# %%
# mean
(tau1_vec_net.mean(),tau2_vec_net.mean(),tau3_vec_net.mean())
# Out:
# (0.8954231425435959, 1.9523564577543995, 0.2078235477727592)

# %%
# confidence interval
print('first outcome:',np.quantile(tau1_vec_net,(0.025,0.975)))
print('second outcome:',np.quantile(tau2_vec_net,(0.025,0.975)))
print('third outcome:',np.quantile(tau3_vec_net,(0.025,0.975)))
# Out:
# first outcome: [0.35491974 1.36696469]
# second outcome: [0.7681788  2.92796321]
# third outcome: [-0.80941953  1.17964555]

# %%
tau1_vec_rer = []
tau2_vec_rer = []
tau3_vec_rer = []
for i in range(z_mat_rer.shape[0]):
    y1_rer,y2_rer,y3_rer = y_gen(x,z_mat_rer[i],tau=tau,err_std=err_std)
    tau1_vec_rer.append(tau_diff(y1_rer,z_mat_rer[i]))
    tau2_vec_rer.append(tau_diff(y2_rer,z_mat_rer[i]))
    tau3_vec_rer.append(tau_diff(y3_rer,z_mat_rer[i]))
tau1_vec_rer = np.array(tau1_vec_rer)
tau2_vec_rer = np.array(tau2_vec_rer)
tau3_vec_rer = np.array(tau3_vec_rer)

# %%
plt.figure()
sb.distplot(tau1_vec_rer,label='tau_rer')
sb.distplot(tau1_vec_net,label='tau_qrwg')
plt.title('First Outcome')
plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure()
sb.distplot(tau2_vec_rer,label='tau_rer')
sb.distplot(tau2_vec_net,label='tau_qrwg')
plt.title('Second Outcome')
plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure()
sb.distplot(tau3_vec_rer,label='tau_rer')
sb.distplot(tau3_vec_net,label='tau_qrwg')
plt.title('Third Outcome')
plt.legend()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Some findings:
# 1. mdiffloss and qqloss can benefit each other. Only mdiffloss leads to very slow convergence as well as loss descent (qqloss almost stay the same). While only qqloss can decrease the mdiff but the mdiffloss would get stuck at a high level. The outcome estimation would also be highly biased. (Mdiff should be larger than QQLoss at first, or the program may stuck into a local optima)
# 2. Only balance linear response surface well. (Single Case)
# 3. Initialization should be normal or uniform, which ensures the diversity of the weights at the initial stage.
# - Potential improvements:
#   1. use qqloss to replace mdiffloss
#   2. use other discrepancy other than mean difference in mdiffloss
